# %%
from pymongo import MongoClient

# Replace this with your actual MongoDB URI
uri = "mongodb+srv://govind:govind2200@boss.atc0cdp.mongodb.net/"  # For local MongoDB
# uri = "mongodb+srv://<username>:<password>@cluster0.mongodb.net"  # For MongoDB Atlas

# Create a client
client = MongoClient(uri)

# Access a database
db = client["ecomerce"]

# Access a collection
collection = db["products"]


# document = {
#     "name": "Product 1",
#     "price": 9.99,
#     "quantity": 10,
#     "category": "Electronics"
# }

# collection.insert_one(document)

# Example: Fetch all documents
# for doc in collection.find():
#     print(doc)

for x in collection.find({"category": "Electronics"}):
    print(x)
client.close()
# Out:
# {'_id': ObjectId('6826ff52829466e3f87ab3f4'), 'name': 'Product 1', 'price': 9.99, 'quantity': 10, 'category': 'Electronics'}

# %% [markdown]
# #### Insert Many

# %%
from pymongo import MongoClient
client =MongoClient("mongodb+srv://govind:govind2200@boss.atc0cdp.mongodb.net/")
client.list_database_names()
# Out:
# ['ecomerce', 'sample_mflix', 'admin', 'local']

# %%
db =client['ecomerce']
db.list_collection_names()
# Out:
# ['products']

# %%
for x in db['products'].find():
    print(x)
# Out:
# {'_id': ObjectId('6825b43a0d1c3f46ef6c4bd8'), 'name': 'Notebook', 'price': 10, 'group': 'A'}
# {'_id': ObjectId('6825b43a0d1c3f46ef6c4bd9'), 'name': 'Pen Set', 'price': 20, 'group': 'B'}
# {'_id': ObjectId('6825b43a0d1c3f46ef6c4bda'), 'name': 'Desk Lamp', 'price': 30, 'group': 'C'}
# {'_id': ObjectId('6825b43a0d1c3f46ef6c4bdb'), 'name': 'Backpack', 'price': 40, 'group': 'A'}
# {'_id': ObjectId('6825b43a0d1c3f46ef6c4bdc'), 'name': 'Wireless Charger', 'price': 50, 'group': 'B'}
# {'_id': ObjectId('6825b43a0d1c3f46ef6c4bdd'), 'name': 'Smart Watch', 'price': 60, 'group': 'C'}
# {'_id': ObjectId('6825b43a0d1c3f46ef6c4bde'), 'name': 'Noise Cancelling Headphones', 'price': 70, 'group': 'A'}
# {'_id': ObjectId('6825b43a0d1c3f46ef6c4bdf'), 'name': 'Portable SSD', 'price': 80, 'group': 'B'}
# {'_id': ObjectId('6825b43a0d1c3f46ef6c4be0'), 'name': 'Tablet Stand', 'price': 90, 'group': 'C'}
# {'_id': ObjectId('6825b43a0d1c3f46ef6c4be1'), 'name': 'Wireless Mouse', 'price': 100, 'group': 'A'}
# ...
